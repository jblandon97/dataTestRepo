# %% [markdown]
# A continuación, se evidencia la implementación de la plantilla de terraform [main.tf](main.tf) para el literal **3.Prueba de AWS Glue**, explicando el paso a paso para verificar la funcionalidad de los componentes:

# %% [markdown]
# 1. Se carga un archivo csv en el bucket de S3

# %% [markdown]
# ![1.upload_to_s3_bucket.png](attachment:1.upload_to_s3_bucket.png)

# %% [markdown]
# 2. Se comprueba que la función lambda ha sido ejecutada justo a la misma hora en la que se cargo el archivo csv en S3

# %% [markdown]
# ![2.check_date_lambda_invocation.png](attachment:2.check_date_lambda_invocation.png)

# %% [markdown]
# 3. Se verifica que el Job de AWS Glue se ha ejecutado al instante con los parametros indicados

# %% [markdown]
# ![3.glue_job_run.png](attachment:3.glue_job_run.png)

# %% [markdown]
# 4. Se consulta la tabla de Dynamo DB para comprobar que se ha escrito la información contenida en el csv:

# %% [markdown]
# ![4.data_in_dydb_table.png](attachment:4.data_in_dydb_table.png)

# %% [markdown]
# 5. Se comprueba en la sección de monitoreo que la información ha sido cargada justo al finalizar la ejecución del Job de AWS Glue:

# %% [markdown]
# ![5.check_date_insert_to_dydb.png](attachment:5.check_date_insert_to_dydb.png)
