# %% [markdown]
# A continuación, se evidencia la implementación de la plantilla de terraform [main.tf](main.tf) para el literal **4. Implementación de servicios serverless con AWS**, explicando el paso a paso para verificar la funcionalidad de los componentes:

# %% [markdown]
# 1. Se carga la siguiente información en la tabla de Dynamo DB a través de AWS CLI utilizando un comando bash:

# %% [markdown]
# ![1.insert_data_to_dydb_table (AWS CLI).png](<attachment:1.insert_data_to_dydb_table (AWS CLI).png>)

# %% [markdown]
# 2. Se comprueba que hay datos en la tabla de Dynamo DB:

# %% [markdown]
# ![2.data_in_dydb_table.png](attachment:2.data_in_dydb_table.png)

# %% [markdown]
# 3. Se chequea la URL de la api rest en API Rest en API Gateway:

# %% [markdown]
# ![3.check_api_url.png](attachment:3.check_api_url.png)

# %% [markdown]
# 4. Se realiza el envío de la petición hacia la api desde Postman y se comprueba que devuelve la información previamente cargada:

# %% [markdown]
# ![4.send_GET_request (postman).png](<attachment:4.send_GET_request (postman).png>)

# %% [markdown]
# 5. Se chequean los id de la API Rest y el recurso asociado para utilzar el el comando de AWS CLI aws apigateway test-invoke-method:

# %% [markdown]
# ![5.check_api_and_rs_id.png](attachment:5.check_api_and_rs_id.png)

# %% [markdown]
# 6. Se utiliza el comando de AWS CLI aws apigateway test-invoke-method en la terminal de vscode:

# %% [markdown]
# ![6.send_GET_request (AWS CLI).png](<attachment:6.send_GET_request (AWS CLI).png>)

# %% [markdown]
# 7. Se comprueba que la lambda ha sido invocada:

# %% [markdown]
# ![7.check_date_lambda_invocation.png](attachment:7.check_date_lambda_invocation.png)
